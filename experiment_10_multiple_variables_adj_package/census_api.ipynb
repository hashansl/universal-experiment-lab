# %%
import requests
import pandas as pd

# %%
# Define base URL for the Census API
base_url = "https://api.census.gov/data/2018/acs/acs5/subject"

# %%
# Define the parameters for the request
params = {
    "get": "group(S0101)",  # Group related to age stratifications
    "for": "county:*",       # Get data for all counties
    "in": "state:48",        # Texas state FIPS code
}

# %%
# Make the API request
response = requests.get(base_url, params=params)

# %%
# Check if the request was successful
if response.status_code == 200:
    data = response.json()
    
    # Convert the data into a pandas DataFrame
    df = pd.DataFrame(data[1:], columns=data[0])  # First row is column headers
    
    # Display the DataFrame
    import ace_tools as tools
    tools.display_dataframe_to_user(name="Texas Age Stratifications", dataframe=df)
    
else:
    print("Error:", response.status_code, response.text)

# %%
import requests
import pandas as pd

# Define base URL for the Census API
base_url = "https://api.census.gov/data/2018/acs/acs5/subject"

# Define the parameters for the request
params = {
    "get": "NAME,S0101_C01_001E,S0101_C01_002E,S0101_C01_003E,S0101_C01_004E,S0101_C01_005E,"
           "S0101_C01_006E,S0101_C01_007E,S0101_C01_008E,S0101_C01_009E,S0101_C01_010E,"
           "S0101_C01_011E,S0101_C01_012E,S0101_C01_013E,S0101_C01_014E,S0101_C01_015E,"
           "S0101_C01_016E,S0101_C01_017E",  # Age-related variables
    "for": "county:*",  # Get data for all counties
    "in": "state:48",   # Texas state FIPS code
}

# Make the API request
response = requests.get(base_url, params=params)

# Check if the request was successful
if response.status_code == 200:
    data = response.json()
    
    # Convert the data into a pandas DataFrame
    df = pd.DataFrame(data[1:], columns=data[0])  # First row is column headers

    # Rename columns for better readability
    df = df.rename(columns={
        "NAME": "County",
        "S0101_C01_001E": "Total Population",
        "S0101_C01_002E": "Under 5 years",
        "S0101_C01_003E": "5 to 9 years",
        "S0101_C01_004E": "10 to 14 years",
        "S0101_C01_005E": "15 to 19 years",
        "S0101_C01_006E": "20 to 24 years",
        "S0101_C01_007E": "25 to 29 years",
        "S0101_C01_008E": "30 to 34 years",
        "S0101_C01_009E": "35 to 39 years",
        "S0101_C01_010E": "40 to 44 years",
        "S0101_C01_011E": "45 to 49 years",
        "S0101_C01_012E": "50 to 54 years",
        "S0101_C01_013E": "55 to 59 years",
        "S0101_C01_014E": "60 to 64 years",
        "S0101_C01_015E": "65 to 69 years",
        "S0101_C01_016E": "70 to 74 years",
        "S0101_C01_017E": "75 years and over"
    })

    # Drop state and county FIPS columns since we have county names
    # df = df.drop(columns=["state", "county"])

    # Convert numeric columns to appropriate types
    for col in df.columns[1:]:  # Skip the 'County' column
        df[col] = pd.to_numeric(df[col], errors='coerce')

    # # Display the DataFrame
    # import ace_tools as tools
    # tools.display_dataframe_to_user(name="Texas County Age Data", dataframe=df)

else:
    print("Error:", response.status_code, response.text)
# Out:
# /Users/h6x/anaconda3/envs/TDA/lib/python3.11/site-packages/pandas/core/arrays/masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (

# %%
df.head()
# Out:
#                    County  Total Population  Under 5 years  5 to 9 years  \
# 0      Ward County, Texas             11586            848           908
# 1  Atascosa County, Texas             48828           3584          3628
# 2     Nolan County, Texas             14966           1094          1183
# 3  Hudspeth County, Texas              4098            207           362
# 4  Harrison County, Texas             66645           4354          4977
#
#    10 to 14 years  15 to 19 years  20 to 24 years  25 to 29 years  \
# 0             902             822             872             819
# 1            4029            3633            3038            3202
# 2            1002            1164             910             746
# 3             280             235             274             308
# 4            4720            4844            3991            3868
#
#    30 to 34 years  35 to 39 years  40 to 44 years  45 to 49 years  \
# ...

# %%
import requests
import pandas as pd

# Define base URL for the Census API
base_url = "https://api.census.gov/data/2018/acs/acs5/subject"

# Define parameters for age groups and sex data
params = {
    "get": "NAME,S0101_C01_001E,"  # Total population
           "S0101_C01_002E,S0101_C01_003E,S0101_C01_004E,S0101_C01_005E,"
           "S0101_C01_006E,S0101_C01_007E,S0101_C01_008E,S0101_C01_009E,"
           "S0101_C01_010E,S0101_C01_011E,S0101_C01_012E,S0101_C01_013E,"
           "S0101_C01_014E,S0101_C01_015E,S0101_C01_016E,S0101_C01_017E,"
           "S0101_C02_001E,S0101_C03_001E",  # Male and Female total counts
    "for": "county:*",  # Get data for all counties
    "in": "state:48",   # Texas state FIPS code
}

# Make the API request
response = requests.get(base_url, params=params)

# Check if the request was successful
if response.status_code == 200:
    data = response.json()
    
    # Convert the data into a pandas DataFrame
    df = pd.DataFrame(data[1:], columns=data[0])  # First row is column headers

    # Rename columns for better readability
    df = df.rename(columns={
        "NAME": "County",
        "S0101_C01_001E": "Total Population",
        "S0101_C01_002E": "Under 5 years",
        "S0101_C01_003E": "5 to 9 years",
        "S0101_C01_004E": "10 to 14 years",
        "S0101_C01_005E": "15 to 19 years",
        "S0101_C01_006E": "20 to 24 years",
        "S0101_C01_007E": "25 to 29 years",
        "S0101_C01_008E": "30 to 34 years",
        "S0101_C01_009E": "35 to 39 years",
        "S0101_C01_010E": "40 to 44 years",
        "S0101_C01_011E": "45 to 49 years",
        "S0101_C01_012E": "50 to 54 years",
        "S0101_C01_013E": "55 to 59 years",
        "S0101_C01_014E": "60 to 64 years",
        "S0101_C01_015E": "65 to 69 years",
        "S0101_C01_016E": "70 to 74 years",
        "S0101_C01_017E": "75 years and over",
        "S0101_C02_001E": "Male Population",
        "S0101_C03_001E": "Female Population"
    })

    # Drop state and county FIPS columns since we have county names
    # df = df.drop(columns=["state", "county"])

    # Convert numeric columns to appropriate types
    for col in df.columns[1:]:  # Skip the 'County' column
        df[col] = pd.to_numeric(df[col], errors='coerce')

    # # Display the DataFrame
    # import ace_tools as tools
    # tools.display_dataframe_to_user(name="Texas County Age & Sex Data", dataframe=df)

else:
    print("Error:", response.status_code, response.text)

# %%
df.head(50)
# Out:
#                       County  Total Population  Under 5 years  5 to 9 years  \
# 0         Ward County, Texas             11586            848           908
# 1     Atascosa County, Texas             48828           3584          3628
# 2        Nolan County, Texas             14966           1094          1183
# 3     Hudspeth County, Texas              4098            207           362
# 4     Harrison County, Texas             66645           4354          4977
# 5       Menard County, Texas              2123             26           140
# 6      Fayette County, Texas             25066           1256          1533
# 7   Williamson County, Texas            527057          35305         39362
# 8   Hutchinson County, Texas             21571           1424          1718
# 9       Morris County, Texas             12424            708           814
# 10      Orange County, Texas             84047           5725          5807
# ...

# %%
df.shape
# Out:
# (254, 22)
