# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import geopandas as gpd

# %%
county = gpd.read_file('/Users/h6x/ORNL/git/WORKSTAION GIT/nvss-experiments/data/SVI2018_US_county.gdb')
tracts = gpd.read_file('/Users/h6x/ORNL/git/WORKSTAION GIT/nvss-experiments/data/SVI2018_US_tract.gdb')

# %%
county.head()
# Out:
#    ST       STATE ST_ABBR      COUNTY   FIPS                       LOCATION  \
# 0  35  NEW MEXICO      NM  Rio Arriba  35039  Rio Arriba County, New Mexico
# 1  01     ALABAMA      AL     Autauga  01001        Autauga County, Alabama
# 2  01     ALABAMA      AL      Blount  01009         Blount County, Alabama
# 3  01     ALABAMA      AL      Butler  01013         Butler County, Alabama
# 4  01     ALABAMA      AL     Calhoun  01015        Calhoun County, Alabama
#
#      AREA_SQMI  E_TOTPOP  M_TOTPOP   E_HU  ...  F_THEME4  F_TOTAL  E_UNINSUR  \
# 0  5860.869195     39307         0  20044  ...         1     -999       4160
# 1   594.443459     55200         0  23315  ...         0        0       3875
# 2   644.830460     57645         0  24222  ...         0        0       6303
# 3   776.838201     20025         0  10026  ...         0        0       2005
# 4   605.867251    115098         0  53682  ...         0        0      10686
#
# ...

# %%
texas_county = county[county.ST_ABBR == 'PA']

# %%
texas_county.columns.to_list()
# Out:
# ['ST',
#  'STATE',
#  'ST_ABBR',
#  'COUNTY',
#  'FIPS',
#  'LOCATION',
#  'AREA_SQMI',
#  'E_TOTPOP',
#  'M_TOTPOP',
#  'E_HU',
#  'M_HU',
#  'E_HH',
#  'M_HH',
#  'E_POV',
#  'M_POV',
#  'E_UNEMP',
#  'M_UNEMP',
#  'E_PCI',
#  'M_PCI',
#  'E_NOHSDP',
#  'M_NOHSDP',
#  'E_AGE65',
#  'M_AGE65',
#  'E_AGE17',
#  'M_AGE17',
#  'E_DISABL',
#  'M_DISABL',
#  'E_SNGPNT',
#  'M_SNGPNT',
#  'E_MINRTY',
#  'M_MINRTY',
#  'E_LIMENG',
#  'M_LIMENG',
#  'E_MUNIT',
#  'M_MUNIT',
#  'E_MOBILE',
#  'M_MOBILE',
#  'E_CROWD',
#  'M_CROWD',
#  'E_NOVEH',
#  'M_NOVEH',
#  'E_GROUPQ',
#  'M_GROUPQ',
#  'EP_POV',
#  'MP_POV',
#  'EP_UNEMP',
#  'MP_UNEMP',
#  'EP_PCI',
#  'MP_PCI',
#  'EP_NOHSDP',
#  'MP_NOHSDP',
#  'EP_AGE65',
#  'MP_AGE65',
#  'EP_AGE17',
#  'MP_AGE17',
#  'EP_DISABL',
#  'MP_DISABL',
#  'EP_SNGPNT',
#  'MP_SNGPNT',
#  'EP_MINRTY',
#  'MP_MINRTY',
#  'EP_LIMENG',
#  'MP_LIMENG',
#  'EP_MUNIT',
#  'MP_MUNIT',
#  'EP_MOBILE',
#  'MP_MOBILE',
#  'EP_CROWD',
#  'MP_CROWD',
#  'EP_NOVEH',
# ...

# %%
import geopandas as gpd
import matplotlib.pyplot as plt

# Assuming 'texas_county' is your GeoDataFrame
fig, ax = plt.subplots(figsize=(10, 6))
texas_county.plot(column='EP_DISABL', legend=False, ax=ax)

# Turn off axis
ax.set_xticks([])
ax.set_yticks([])
ax.set_frame_on(False)

plt.show()

# %%
# sort by EP_DISABL

texas_county = texas_county.sort_values(by='EP_DISABL', ascending=False)

# %%
texas_county[['FIPS','EP_DISABL']].head()
# Out:
#        FIPS  EP_DISABL
# 2644  47067       27.1
# 1966  47005       26.9
# 2912  47007       26.8
# 2649  47151       25.9
# 2369  47013       25.1

# %%
tracts.head()
# Out:
#    ST    STATE ST_ABBR STCNTY   COUNTY         FIPS  \
# 0  01  ALABAMA      AL  01015  Calhoun  01015981901
# 1  01  ALABAMA      AL  01015  Calhoun  01015981902
# 2  01  ALABAMA      AL  01015  Calhoun  01015981903
# 3  01  ALABAMA      AL  01097   Mobile  01097003605
# 4  01  ALABAMA      AL  01097   Mobile  01097990000
#
#                                         LOCATION  AREA_SQMI  E_TOTPOP  \
# 0  Census Tract 9819.01, Calhoun County, Alabama  24.243865         0
# 1  Census Tract 9819.02, Calhoun County, Alabama  34.646714         0
# 2  Census Tract 9819.03, Calhoun County, Alabama  13.926276         0
# 3     Census Tract 36.05, Mobile County, Alabama   0.732300       899
# 4      Census Tract 9900, Mobile County, Alabama   0.000000         0
#
#    M_TOTPOP  ...  F_THEME4  F_TOTAL  E_UNINSUR  M_UNINSUR  EP_UNINSUR  \
# 0        12  ...      -999     -999          0         12      -999.0
# 1        12  ...      -999     -999          0         12      -999.0
# ...

# %%
# get the row count per each county
tracts_count = tracts.groupby('STCNTY').size().reset_index(name='count')

# %%
# sort by count
tracts_count = tracts_count.sort_values(by='count', ascending=False)

# %%
tracts_count[tracts_count['count'] <30].head(10)
# Out:
#      STCNTY  count
# 1386  27145     29
# 2616  48187     29
# 2284  42081     29
# 2139  40017     29
# 2315  44009     29
# 640   17091     29
# 283   08077     29
# 2997  54011     29
# 564   16027     29
# 314   09013     29

# %%
# get STCNTY starts with 42
tracts_count[tracts_count['STCNTY'].astype(str).str.startswith('42')].head(15)
# Out:
#      STCNTY  count
# 2245  42003    402
# 2294  42101    384
# 2289  42091    211
# 2266  42045    144
# 2252  42017    143
# 2258  42029    116
# 2283  42079    104
# 2308  42129    100
# 2279  42071     98
# 2249  42011     90
# 2310  42133     90
# 2282  42077     76
# 2268  42049     71
# 2291  42095     68
# 2265  42043     65

# %%
single = tracts[tracts.STCNTY == '42095']

# Assuming 'texas_county' is your GeoDataFrame
fig, ax = plt.subplots(figsize=(10, 6))
single.plot(column='EP_DISABL', legend=False, ax=ax)

# Turn off axis
ax.set_xticks([])
ax.set_yticks([])
ax.set_frame_on(False)

plt.show()
